# %% [markdown]
# CloudZero Technical Challenge
# ---
#
# ### Technical interview introduction:
#
# We find that interviews can be stressful, and generally at your job you aren’t solving problems under that kind of stress.  To allow people showcase their skills in a more natural environment, we’ve created a take-home problem that we ask candidates to solve. These problems should allow people to demonstrate how they solve problems with code, which is what anyone joining the engineering team would do day to day.
#
# While we recognize that a take home problem has its own downsides, chief among them it’s a non-trivial request on time from people who are already busy (see below for other options,) we believe that any interview process requires a significant time commitment and this is one that gives us a better objective measure of how candidates would solve the types of problems necessary to thrive at CloudZero.
#
# Please note, if you feel that you cannot find the time to work on the below problem then we will happily facilitate one of two other options.
#
# First, if you have code that you can send us (an open source project, or something you’ve worked on for an employer or client that you can share,) feel free to send us that.  We ask that it show off your ability with Python and AWS and be something that you were the primary decision maker and coder on.  Please also ensure that it is something we can execute ourselves.
#
# The second option is that we will allow you to pair-program a problem during one hour of the interview process.  The problem will be given to you at the interview, and we’ll help with a laptop and IDE and an engineer to pair with.
#
# Please indicate your preference between these three options as early as possible so that we can plan for a good experience.
#
# ### The problem:
# For the problem below, we’d like you produce code that solves the problem and get it to us before we have you come in so that we can evaluate the solution. We will review the output with you when you come in. Sending us to a GitHub repo is probably easiest, but if you prefer getting us your solution in another way that is fine as well. Take the time you need and feel free to reach out if any part of the problem is unclear.
#
# Using Python 3.6+, create a system that analyzes the Alexa top 1,000 sites.  The analysis should include:
#  * Per Site
#    * Word count of the first page
#    * Rank across all sites based off the word count
#    * Duration of the scan
#  * Across All Sites
#    * AVG word count of the first page
#    * Top 20 HTTP headers and the percentage of sites they were seen in
#    * Duration of the entire scan
#
# You may use any library or AWS service that you desire as long as your system is installable by us.  Don't over-engineer the solution; keep it simple, elegant and functional.  Your solution should run to completion within 15 minutes.
#
# Please be aware, the cost for calling some AWS services and APIs can add up quickly.  You may want to watch that as you develop so that you don't incur an unexpectedly expense during development!

# %%
import boto3

# %%
session = boto3.Session(profile_name='personal')
client = session.client('alexaforbusiness')

# %%
test_json = open("test.json", "r")

# %%
import json

# %%
hundred_sites = json.load(test_json)

# %%
hundred_sites
# Out:
# {'Ats': {'OperationRequest': {'RequestId': 'e314e05a-8302-11e9-92f2-6572acfe38de'},
#   'Results': {'Result': {'Alexa': {'Request': {'Arguments': {'Argument': [{'Name': 'countrycode',
#          'Value': 'US'},
#         {'Name': 'count', 'Value': '100'},
#         {'Name': 'responsegroup', 'Value': 'Country'}]}},
#      'TopSites': {'Country': {'CountryName': 'United States',
#        'CountryCode': 'US',
#        'TotalSites': '392675',
#        'Sites': {'Site': [{'DataUrl': 'google.com',
#           'Country': {'Rank': '1',
#            'Reach': {'PerMillion': '826100'},
#            'PageViews': {'PerMillion': '239430', 'PerUser': '12.61'}},
#           'Global': {'Rank': '1'}},
#          {'DataUrl': 'youtube.com',
#           'Country': {'Rank': '2',
#            'Reach': {'PerMillion': '440200'},
#            'PageViews': {'PerMillion': '46010', 'PerUser': '4.55'}},
#           'Global': {'Rank': '2'}},
#          {'DataUrl': 'facebook.com',
#           'Country': {'Rank': '3',
#            'Reach': {'PerMillion': '235000'},
#            'PageViews': {'PerMillion': '17750', 'PerUser': '3.29'}},
#           'Global': {'Rank': '3'}},
#          {'DataUrl': 'amazon.com',
#           'Country': {'Rank': '4',
#            'Reach': {'PerMillion': '174700'},
#            'PageViews': {'PerMillion': '33870', 'PerUser': '8.44'}},
#           'Global': {'Rank': '10'}},
#          {'DataUrl': 'reddit.com',
#           'Country': {'Rank': '5',
#            'Reach': {'PerMillion': '107500'},
#            'PageViews': {'PerMillion': '18050', 'PerUser': '7.3'}},
#           'Global': {'Rank': '13'}},
#          {'DataUrl': 'wikipedia.org',
#           'Country': {'Rank': '6',
#            'Reach': {'PerMillion': '108600'},
#            'PageViews': {'PerMillion': '8298', 'PerUser': '3.32'}},
#           'Global': {'Rank': '5'}},
#          {'DataUrl': 'yahoo.com',
#           'Country': {'Rank': '7',
#            'Reach': {'PerMillion': '86820'},
#            'PageViews': {'PerMillion': '6974', 'PerUser': '3.5'}},
#           'Global': {'Rank': '9'}},
#          {'DataUrl': 'twitter.com',
#           'Country': {'Rank': '8',
#            'Reach': {'PerMillion': '87920'},
#            'PageViews': {'PerMillion': '5988', 'PerUser': '2.96'}},
#           'Global': {'Rank': '12'}},
#          {'DataUrl': 'instagram.com',
#           'Country': {'Rank': '9',
#            'Reach': {'PerMillion': '56690'},
#            'PageViews': {'PerMillion': '4651', 'PerUser': '3.57'}},
#           'Global': {'Rank': '14'}},
#          {'DataUrl': 'linkedin.com',
#           'Country': {'Rank': '10',
#            'Reach': {'PerMillion': '51230'},
#            'PageViews': {'PerMillion': '6103', 'PerUser': '5.18'}},
#           'Global': {'Rank': '25'}},
#          {'DataUrl': 'ebay.com',
#           'Country': {'Rank': '11',
#            'Reach': {'PerMillion': '42030'},
#            'PageViews': {'PerMillion': '7011', 'PerUser': '7.26'}},
#           'Global': {'Rank': '40'}},
#          {'DataUrl': 'netflix.com',
#           'Country': {'Rank': '12',
#            'Reach': {'PerMillion': '58860'},
#            'PageViews': {'PerMillion': '2216', 'PerUser': '1.64'}},
#           'Global': {'Rank': '24'}},
#          {'DataUrl': 'twitch.tv',
#           'Country': {'Rank': '13',
#            'Reach': {'PerMillion': '48070'},
#            'PageViews': {'PerMillion': '3299', 'PerUser': '2.99'}},
#           'Global': {'Rank': '26'}},
#          {'DataUrl': 'microsoftonline.com',
#           'Country': {'Rank': '14',
#            'Reach': {'PerMillion': '51850'},
#            'PageViews': {'PerMillion': '2184', 'PerUser': '1.83'}},
#           'Global': {'Rank': '33'}},
#          {'DataUrl': 'pornhub.com',
#           'Country': {'Rank': '15',
#            'Reach': {'PerMillion': '32840'},
#            'PageViews': {'PerMillion': '2709', 'PerUser': '3.59'}},
#           'Global': {'Rank': '28'}},
#          {'DataUrl': 'imgur.com',
#           'Country': {'Rank': '16',
#            'Reach': {'PerMillion': '33830'},
#            'PageViews': {'PerMillion': '1924', 'PerUser': '2.47'}},
#           'Global': {'Rank': '58'}},
#          {'DataUrl': 'craigslist.org',
#           'Country': {'Rank': '17',
#            'Reach': {'PerMillion': '23290'},
#            'PageViews': {'PerMillion': '4330', 'PerUser': '8.09'}},
#           'Global': {'Rank': '113'}},
#          {'DataUrl': 'live.com',
#           'Country': {'Rank': '18',
#            'Reach': {'PerMillion': '28650'},
#            'PageViews': {'PerMillion': '2199', 'PerUser': '3.34'}},
#           'Global': {'Rank': '15'}},
#          {'DataUrl': 'paypal.com',
#           'Country': {'Rank': '19',
#            'Reach': {'PerMillion': '24060'},
#            'PageViews': {'PerMillion': '2680', 'PerUser': '4.85'}},
#           'Global': {'Rank': '56'}},
#          {'DataUrl': 'chase.com',
#           'Country': {'Rank': '20',
#            'Reach': {'PerMillion': '25190'},
#            'PageViews': {'PerMillion': '2303', 'PerUser': '3.98'}},
#           'Global': {'Rank': '129'}},
#          {'DataUrl': 'bing.com',
#           'Country': {'Rank': '21',
#            'Reach': {'PerMillion': '27640'},
#            'PageViews': {'PerMillion': '1651', 'PerUser': '2.6'}},
#           'Global': {'Rank': '38'}},
#          {'DataUrl': 'instructure.com',
#           'Country': {'Rank': '22',
#            'Reach': {'PerMillion': '19910'},
#            'PageViews': {'PerMillion': '3859', 'PerUser': '8.44'}},
#           'Global': {'Rank': '124'}},
#          {'DataUrl': 'espn.com',
#           'Country': {'Rank': '23',
#            'Reach': {'PerMillion': '27000'},
#            'PageViews': {'PerMillion': '1548', 'PerUser': '2.49'}},
#           'Global': {'Rank': '116'}},
#          {'DataUrl': 'fandom.com',
#           'Country': {'Rank': '24',
#            'Reach': {'PerMillion': '22700'},
#            'PageViews': {'PerMillion': '2324', 'PerUser': '4.45'}},
#           'Global': {'Rank': '55'}},
#          {'DataUrl': 'cnn.com',
#           'Country': {'Rank': '25',
#            'Reach': {'PerMillion': '27240'},
#            'PageViews': {'PerMillion': '1424', 'PerUser': '2.27'}},
#           'Global': {'Rank': '102'}},
#          {'DataUrl': 'imdb.com',
#           'Country': {'Rank': '26',
#            'Reach': {'PerMillion': '21760'},
#            'PageViews': {'PerMillion': '1976', 'PerUser': '3.95'}},
#           'Global': {'Rank': '48'}},
#          {'DataUrl': 'pinterest.com',
#           'Country': {'Rank': '27',
#            'Reach': {'PerMillion': '22400'},
#            'PageViews': {'PerMillion': '1643', 'PerUser': '3.19'}},
#           'Global': {'Rank': '69'}},
#          {'DataUrl': 't.co',
#           'Country': {'Rank': '28',
#            'Reach': {'PerMillion': '26010'},
#            'PageViews': {'PerMillion': '1179', 'PerUser': '1.97'}},
#           'Global': {'Rank': '41'}},
#          {'DataUrl': 'nytimes.com',
#           'Country': {'Rank': '29',
#            'Reach': {'PerMillion': '23420'},
#            'PageViews': {'PerMillion': '1236', 'PerUser': '2.3'}},
#           'Global': {'Rank': '114'}},
#          {'DataUrl': 'office.com',
#           'Country': {'Rank': '30',
#            'Reach': {'PerMillion': '20960'},
#            'PageViews': {'PerMillion': '1483', 'PerUser': '3.08'}},
#           'Global': {'Rank': '50'}},
#          {'DataUrl': 'hulu.com',
#           'Country': {'Rank': '31',
#            'Reach': {'PerMillion': '24710'},
#            'PageViews': {'PerMillion': '986.7', 'PerUser': '1.74'}},
#           'Global': {'Rank': '172'}},
#          {'DataUrl': 'okezone.com',
#           'Country': {'Rank': '32',
#            'Reach': {'PerMillion': '43804.35'},
#            'PageViews': {'PerMillion': '1896.47', 'PerUser': '1.88'}},
#           'Global': {'Rank': '54'}},
#          {'DataUrl': 'microsoft.com',
#           'Country': {'Rank': '33',
#            'Reach': {'PerMillion': '19930'},
#            'PageViews': {'PerMillion': '1346', 'PerUser': '2.94'}},
#           'Global': {'Rank': '37'}},
#          {'DataUrl': 'github.com',
#           'Country': {'Rank': '34',
#            'Reach': {'PerMillion': '17200'},
#            'PageViews': {'PerMillion': '1992', 'PerUser': '5.04'}},
#           'Global': {'Rank': '46'}},
#          {'DataUrl': 'salesforce.com',
#           'Country': {'Rank': '35',
#            'Reach': {'PerMillion': '13200'},
#            'PageViews': {'PerMillion': '4525', 'PerUser': '14.9'}},
#           'Global': {'Rank': '119'}},
#          {'DataUrl': 'force.com',
#           'Country': {'Rank': '36',
#            'Reach': {'PerMillion': '14300'},
#            'PageViews': {'PerMillion': '3147', 'PerUser': '9.55'}},
#           'Global': {'Rank': '115'}},
#          {'DataUrl': 'zillow.com',
#           'Country': {'Rank': '37',
#            'Reach': {'PerMillion': '17100'},
#            'PageViews': {'PerMillion': '1747', 'PerUser': '4.44'}},
#           'Global': {'Rank': '196'}},
#          {'DataUrl': 'walmart.com',
#           'Country': {'Rank': '38',
#            'Reach': {'PerMillion': '17300'},
#            'PageViews': {'PerMillion': '1570', 'PerUser': '3.94'}},
#           'Global': {'Rank': '166'}},
#          {'DataUrl': 'yelp.com',
#           'Country': {'Rank': '39',
#            'Reach': {'PerMillion': '18110'},
#            'PageViews': {'PerMillion': '1358', 'PerUser': '3.26'}},
#           'Global': {'Rank': '198'}},
#          {'DataUrl': 'weather.com',
#           'Country': {'Rank': '40',
#            'Reach': {'PerMillion': '18520'},
#            'PageViews': {'PerMillion': '1086', 'PerUser': '2.55'}},
#           'Global': {'Rank': '200'}},
#          {'DataUrl': 'apple.com',
#           'Country': {'Rank': '41',
#            'Reach': {'PerMillion': '17300'},
#            'PageViews': {'PerMillion': '1250', 'PerUser': '3.15'}},
#           'Global': {'Rank': '61'}},
#          {'DataUrl': 'bankofamerica.com',
#           'Country': {'Rank': '42',
#            'Reach': {'PerMillion': '14000'},
#            'PageViews': {'PerMillion': '1863', 'PerUser': '5.81'}},
#           'Global': {'Rank': '215'}},
#          {'DataUrl': 'tumblr.com',
#           'Country': {'Rank': '43',
#            'Reach': {'PerMillion': '14000'},
#            'PageViews': {'PerMillion': '1684', 'PerUser': '5.25'}},
#           'Global': {'Rank': '74'}},
#          {'DataUrl': 'stackoverflow.com',
#           'Country': {'Rank': '44',
#            'Reach': {'PerMillion': '15500'},
#            'PageViews': {'PerMillion': '1260', 'PerUser': '3.54'}},
#           'Global': {'Rank': '51'}},
#          {'DataUrl': 'dropbox.com',
#           'Country': {'Rank': '45',
#            'Reach': {'PerMillion': '15900'},
#            'PageViews': {'PerMillion': '1102', 'PerUser': '3.02'}},
#           'Global': {'Rank': '77'}},
#          {'DataUrl': 'livejasmin.com',
#           'Country': {'Rank': '46',
#            'Reach': {'PerMillion': '30491.73'},
#            'PageViews': {'PerMillion': '1031', 'PerUser': '1.47'}},
#           'Global': {'Rank': '52'}},
#          {'DataUrl': 'xvideos.com',
#           'Country': {'Rank': '47',
#            'Reach': {'PerMillion': '11500'},
#            'PageViews': {'PerMillion': '2624', 'PerUser': '9.96'}},
#           'Global': {'Rank': '47'}},
#          {'DataUrl': 'wellsfargo.com',
#           'Country': {'Rank': '48',
#            'Reach': {'PerMillion': '13400'},
#            'PageViews': {'PerMillion': '1505', 'PerUser': '4.9'}},
#           'Global': {'Rank': '239'}},
#          {'DataUrl': 'indeed.com',
#           'Country': {'Rank': '49',
#            'Reach': {'PerMillion': '14000'},
#            'PageViews': {'PerMillion': '1200', 'PerUser': '3.74'}},
#           'Global': {'Rank': '137'}},
#          {'DataUrl': 'quora.com',
#           'Country': {'Rank': '50',
#            'Reach': {'PerMillion': '18510'},
#            'PageViews': {'PerMillion': '651.4', 'PerUser': '1.53'}},
#           'Global': {'Rank': '80'}},
#          {'DataUrl': 'etsy.com',
#           'Country': {'Rank': '51',
#            'Reach': {'PerMillion': '12400'},
#            'PageViews': {'PerMillion': '1626', 'PerUser': '5.71'}},
#           'Global': {'Rank': '144'}},
#          {'DataUrl': 'amazonaws.com',
#           'Country': {'Rank': '52',
#            'Reach': {'PerMillion': '15500'},
#            'PageViews': {'PerMillion': '775.4', 'PerUser': '2.18'}},
#           'Global': {'Rank': '98'}},
#          {'DataUrl': 'adobe.com',
#           'Country': {'Rank': '53',
#            'Reach': {'PerMillion': '13800'},
#            'PageViews': {'PerMillion': '978.4', 'PerUser': '3.08'}},
#           'Global': {'Rank': '62'}},
#          {'DataUrl': 'blogspot.com',
#           'Country': {'Rank': '54',
#            'Reach': {'PerMillion': '15100'},
#            'PageViews': {'PerMillion': '737.7', 'PerUser': '2.13'}},
#           'Global': {'Rank': '23'}},
#          {'DataUrl': 'quizlet.com',
#           'Country': {'Rank': '55',
#            'Reach': {'PerMillion': '12000'},
#            'PageViews': {'PerMillion': '1223', 'PerUser': '4.42'}},
#           'Global': {'Rank': '219'}},
#          {'DataUrl': 'spotify.com',
#           'Country': {'Rank': '56',
#            'Reach': {'PerMillion': '13300'},
#            'PageViews': {'PerMillion': '888.7', 'PerUser': '2.9'}},
#           'Global': {'Rank': '107'}},
#          {'DataUrl': 'msn.com',
#           'Country': {'Rank': '57',
#            'Reach': {'PerMillion': '12400'},
#            'PageViews': {'PerMillion': '1010', 'PerUser': '3.54'}},
#           'Global': {'Rank': '53'}},
#          {'DataUrl': 'foxnews.com',
#           'Country': {'Rank': '58',
#            'Reach': {'PerMillion': '12800'},
#            'PageViews': {'PerMillion': '904', 'PerUser': '3.08'}},
#           'Global': {'Rank': '253'}},
#          {'DataUrl': 'xfinity.com',
#           'Country': {'Rank': '59',
#            'Reach': {'PerMillion': '12500'},
#            'PageViews': {'PerMillion': '932.1', 'PerUser': '3.25'}},
#           'Global': {'Rank': '291'}},
#          {'DataUrl': 'homedepot.com',
#           'Country': {'Rank': '60',
#            'Reach': {'PerMillion': '11200'},
#            'PageViews': {'PerMillion': '1183', 'PerUser': '4.58'}},
#           'Global': {'Rank': '284'}},
#          {'DataUrl': 'discordapp.com',
#           'Country': {'Rank': '61',
#            'Reach': {'PerMillion': '13700'},
#            'PageViews': {'PerMillion': '681.2', 'PerUser': '2.17'}},
#           'Global': {'Rank': '118'}},
#          {'DataUrl': 'soundcloud.com',
#           'Country': {'Rank': '62',
#            'Reach': {'PerMillion': '12300'},
#            'PageViews': {'PerMillion': '579.1', 'PerUser': '2.05'}},
#           'Global': {'Rank': '108'}},
#          {'DataUrl': 'wordpress.com',
#           'Country': {'Rank': '63',
#            'Reach': {'PerMillion': '12000'},
#            'PageViews': {'PerMillion': '597.5', 'PerUser': '2.17'}},
#           'Global': {'Rank': '57'}},
#          {'DataUrl': 'okta.com',
#           'Country': {'Rank': '64',
#            'Reach': {'PerMillion': '10400'},
#            'PageViews': {'PerMillion': '715', 'PerUser': '2.99'}},
#           'Global': {'Rank': '255'}},
#          {'DataUrl': 'stackexchange.com',
#           'Country': {'Rank': '65',
#            'Reach': {'PerMillion': '12100'},
#            'PageViews': {'PerMillion': '504.9', 'PerUser': '1.81'}},
#           'Global': {'Rank': '117'}},
#          {'DataUrl': 'nih.gov',
#           'Country': {'Rank': '66',
#            'Reach': {'PerMillion': '10600'},
#            'PageViews': {'PerMillion': '669.5', 'PerUser': '2.75'}},
#           'Global': {'Rank': '111'}},
#          {'DataUrl': 'bestbuy.com',
#           'Country': {'Rank': '67',
#            'Reach': {'PerMillion': '9570'},
#            'PageViews': {'PerMillion': '799.4', 'PerUser': '3.64'}},
#           'Global': {'Rank': '297'}},
#          {'DataUrl': 'breitbart.com',
#           'Country': {'Rank': '68',
#            'Reach': {'PerMillion': '15846.49'},
#            'PageViews': {'PerMillion': '1312.44', 'PerUser': '3.6'}},
#           'Global': {'Rank': '336'}},
#          {'DataUrl': 'zoom.us',
#           'Country': {'Rank': '69',
#            'Reach': {'PerMillion': '10500'},
#            'PageViews': {'PerMillion': '630.2', 'PerUser': '2.61'}},
#           'Global': {'Rank': '207'}},
#          {'DataUrl': 'capitalone.com',
#           'Country': {'Rank': '70',
#            'Reach': {'PerMillion': '9070'},
#            'PageViews': {'PerMillion': '822.1', 'PerUser': '3.94'}},
#           'Global': {'Rank': '377'}},
#          {'DataUrl': 'xhamster.com',
#           'Country': {'Rank': '71',
#            'Reach': {'PerMillion': '7240'},
#            'PageViews': {'PerMillion': '1633', 'PerUser': '9.82'}},
#           'Global': {'Rank': '59'}},
#          {'DataUrl': 'usps.com',
#           'Country': {'Rank': '72',
#            'Reach': {'PerMillion': '10200'},
#            'PageViews': {'PerMillion': '605.8', 'PerUser': '2.59'}},
#           'Global': {'Rank': '345'}},
#          {'DataUrl': 'airbnb.com',
#           'Country': {'Rank': '73',
#            'Reach': {'PerMillion': '8080'},
#            'PageViews': {'PerMillion': '1062', 'PerUser': '5.72'}},
#           'Global': {'Rank': '251'}},
#          {'DataUrl': 'intuit.com',
#           'Country': {'Rank': '74',
#            'Reach': {'PerMillion': '9060'},
#            'PageViews': {'PerMillion': '742', 'PerUser': '3.56'}},
#           'Global': {'Rank': '333'}},
#          {'DataUrl': 'bbc.com',
#           'Country': {'Rank': '75',
#            'Reach': {'PerMillion': '10000'},
#            'PageViews': {'PerMillion': '565.3', 'PerUser': '2.46'}},
#           'Global': {'Rank': '86'}},
#          {'DataUrl': 'redd.it',
#           'Country': {'Rank': '76',
#            'Reach': {'PerMillion': '10700'},
#            'PageViews': {'PerMillion': '479.8', 'PerUser': '1.96'}},
#           'Global': {'Rank': '224'}},
#          {'DataUrl': 'slickdeals.net',
#           'Country': {'Rank': '77',
#            'Reach': {'PerMillion': '9330'},
#            'PageViews': {'PerMillion': '553.7', 'PerUser': '2.58'}},
#           'Global': {'Rank': '423'}},
#          {'DataUrl': 'washingtonpost.com',
#           'Country': {'Rank': '78',
#            'Reach': {'PerMillion': '9620'},
#            'PageViews': {'PerMillion': '500', 'PerUser': '2.26'}},
#           'Global': {'Rank': '282'}},
#          {'DataUrl': 'gamepedia.com',
#           'Country': {'Rank': '79',
#            'Reach': {'PerMillion': '7570'},
#            'PageViews': {'PerMillion': '887.5', 'PerUser': '5.1'}},
#           'Global': {'Rank': '167'}},
#          {'DataUrl': 'slack.com',
#           'Country': {'Rank': '80',
#            'Reach': {'PerMillion': '8190'},
#            'PageViews': {'PerMillion': '678.5', 'PerUser': '3.61'}},
#           'Global': {'Rank': '179'}},
#          {'DataUrl': 'patch.com',
#           'Country': {'Rank': '81',
#            'Reach': {'PerMillion': '16650.53'},
#            'PageViews': {'PerMillion': '717.06', 'PerUser': '1.87'}},
#           'Global': {'Rank': '453'}},
#          {'DataUrl': 'godaddy.com',
#           'Country': {'Rank': '82',
#            'Reach': {'PerMillion': '7190'},
#            'PageViews': {'PerMillion': '966.3', 'PerUser': '5.85'}},
#           'Global': {'Rank': '157'}},
#          {'DataUrl': 'chaturbate.com',
#           'Country': {'Rank': '83',
#            'Reach': {'PerMillion': '6340'},
#            'PageViews': {'PerMillion': '1454', 'PerUser': '9.99'}},
#           'Global': {'Rank': '145'}},
#          {'DataUrl': 'tripadvisor.com',
#           'Country': {'Rank': '84',
#            'Reach': {'PerMillion': '8660'},
#            'PageViews': {'PerMillion': '568.5', 'PerUser': '2.86'}},
#           'Global': {'Rank': '263'}},
#          {'DataUrl': 'target.com',
#           'Country': {'Rank': '85',
#            'Reach': {'PerMillion': '8550'},
#            'PageViews': {'PerMillion': '563.2', 'PerUser': '2.87'}},
#           'Global': {'Rank': '436'}},
#          {'DataUrl': 'roblox.com',
#           'Country': {'Rank': '86',
#            'Reach': {'PerMillion': '6220'},
#            'PageViews': {'PerMillion': '1384', 'PerUser': '9.67'}},
#           'Global': {'Rank': '90'}},
#          {'DataUrl': 'buzzfeed.com',
#           'Country': {'Rank': '87',
#            'Reach': {'PerMillion': '7720'},
#            'PageViews': {'PerMillion': '682', 'PerUser': '3.84'}},
#           'Global': {'Rank': '259'}},
#          {'DataUrl': 'baidu.com',
#           'Country': {'Rank': '88',
#            'Reach': {'PerMillion': '7370'},
#            'PageViews': {'PerMillion': '729.1', 'PerUser': '4.3'}},
#           'Global': {'Rank': '4'}},
#          {'DataUrl': 'myshopify.com',
#           'Country': {'Rank': '89',
#            'Reach': {'PerMillion': '6130'},
#            'PageViews': {'PerMillion': '1286', 'PerUser': '9.13'}},
#           'Global': {'Rank': '216'}},
#          {'DataUrl': 'vice.com',
#           'Country': {'Rank': '90',
#            'Reach': {'PerMillion': '15955.17'},
#            'PageViews': {'PerMillion': '504.66', 'PerUser': '1.38'}},
#           'Global': {'Rank': '201'}},
#          {'DataUrl': 'citi.com',
#           'Country': {'Rank': '91',
#            'Reach': {'PerMillion': '6270'},
#            'PageViews': {'PerMillion': '954.9', 'PerUser': '6.62'}},
#           'Global': {'Rank': '489'}},
#          {'DataUrl': 'aol.com',
#           'Country': {'Rank': '92',
#            'Reach': {'PerMillion': '7410'},
#            'PageViews': {'PerMillion': '570.9', 'PerUser': '3.35'}},
#           'Global': {'Rank': '361'}},
#          {'DataUrl': 'vimeo.com',
#           'Country': {'Rank': '93',
#            'Reach': {'PerMillion': '7730'},
#            'PageViews': {'PerMillion': '508.6', 'PerUser': '2.86'}},
#           'Global': {'Rank': '128'}},
#          {'DataUrl': 'americanexpress.com',
#           'Country': {'Rank': '94',
#            'Reach': {'PerMillion': '7240'},
#            'PageViews': {'PerMillion': '588.2', 'PerUser': '3.54'}},
#           'Global': {'Rank': '348'}},
#          {'DataUrl': 'steamcommunity.com',
#           'Country': {'Rank': '95',
#            'Reach': {'PerMillion': '8450'},
#            'PageViews': {'PerMillion': '410', 'PerUser': '2.11'}},
#           'Global': {'Rank': '147'}},
#          {'DataUrl': 'glassdoor.com',
#           'Country': {'Rank': '96',
#            'Reach': {'PerMillion': '7080'},
#            'PageViews': {'PerMillion': '596', 'PerUser': '3.67'}},
#           'Global': {'Rank': '414'}},
#          {'DataUrl': 'gfycat.com',
#           'Country': {'Rank': '97',
#            'Reach': {'PerMillion': '11663.11'},
#            'PageViews': {'PerMillion': '825.27', 'PerUser': '3.08'}},
#           'Global': {'Rank': '260'}},
#          {'DataUrl': 'xnxx.com',
#           'Country': {'Rank': '98',
#            'Reach': {'PerMillion': '5230'},
#            'PageViews': {'PerMillion': '1246', 'PerUser': '10.4'}},
#           'Global': {'Rank': '99'}},
#          {'DataUrl': 'ups.com',
#           'Country': {'Rank': '99',
#            'Reach': {'PerMillion': '7760'},
#            'PageViews': {'PerMillion': '360', 'PerUser': '2.02'}},
#           'Global': {'Rank': '406'}},
#          {'DataUrl': 'tmall.com',
#           'Country': {'Rank': '100',
#            'Reach': {'PerMillion': '6470'},
#            'PageViews': {'PerMillion': '517.5', 'PerUser': '3.48'}},
#           'Global': {'Rank': '7'}}]}}}}},
#    'ResponseStatus': {'StatusCode': '200'}}}}

# %%
hundred_sites=hundred_sites['Ats']['Results']['Result']['Alexa']['TopSites']['Country']['Sites']['Site']

# %%
test_json.close()

# %%
hundred_sites
# Out:
# [{'DataUrl': 'google.com',
#   'Country': {'Rank': '1',
#    'Reach': {'PerMillion': '826100'},
#    'PageViews': {'PerMillion': '239430', 'PerUser': '12.61'}},
#   'Global': {'Rank': '1'}},
#  {'DataUrl': 'youtube.com',
#   'Country': {'Rank': '2',
#    'Reach': {'PerMillion': '440200'},
#    'PageViews': {'PerMillion': '46010', 'PerUser': '4.55'}},
#   'Global': {'Rank': '2'}},
#  {'DataUrl': 'facebook.com',
#   'Country': {'Rank': '3',
#    'Reach': {'PerMillion': '235000'},
#    'PageViews': {'PerMillion': '17750', 'PerUser': '3.29'}},
#   'Global': {'Rank': '3'}},
#  {'DataUrl': 'amazon.com',
#   'Country': {'Rank': '4',
#    'Reach': {'PerMillion': '174700'},
#    'PageViews': {'PerMillion': '33870', 'PerUser': '8.44'}},
#   'Global': {'Rank': '10'}},
#  {'DataUrl': 'reddit.com',
#   'Country': {'Rank': '5',
#    'Reach': {'PerMillion': '107500'},
#    'PageViews': {'PerMillion': '18050', 'PerUser': '7.3'}},
#   'Global': {'Rank': '13'}},
#  {'DataUrl': 'wikipedia.org',
#   'Country': {'Rank': '6',
#    'Reach': {'PerMillion': '108600'},
#    'PageViews': {'PerMillion': '8298', 'PerUser': '3.32'}},
#   'Global': {'Rank': '5'}},
#  {'DataUrl': 'yahoo.com',
#   'Country': {'Rank': '7',
#    'Reach': {'PerMillion': '86820'},
#    'PageViews': {'PerMillion': '6974', 'PerUser': '3.5'}},
#   'Global': {'Rank': '9'}},
#  {'DataUrl': 'twitter.com',
#   'Country': {'Rank': '8',
#    'Reach': {'PerMillion': '87920'},
#    'PageViews': {'PerMillion': '5988', 'PerUser': '2.96'}},
#   'Global': {'Rank': '12'}},
#  {'DataUrl': 'instagram.com',
#   'Country': {'Rank': '9',
#    'Reach': {'PerMillion': '56690'},
#    'PageViews': {'PerMillion': '4651', 'PerUser': '3.57'}},
#   'Global': {'Rank': '14'}},
#  {'DataUrl': 'linkedin.com',
#   'Country': {'Rank': '10',
#    'Reach': {'PerMillion': '51230'},
#    'PageViews': {'PerMillion': '6103', 'PerUser': '5.18'}},
#   'Global': {'Rank': '25'}},
#  {'DataUrl': 'ebay.com',
#   'Country': {'Rank': '11',
#    'Reach': {'PerMillion': '42030'},
#    'PageViews': {'PerMillion': '7011', 'PerUser': '7.26'}},
#   'Global': {'Rank': '40'}},
#  {'DataUrl': 'netflix.com',
#   'Country': {'Rank': '12',
#    'Reach': {'PerMillion': '58860'},
#    'PageViews': {'PerMillion': '2216', 'PerUser': '1.64'}},
#   'Global': {'Rank': '24'}},
#  {'DataUrl': 'twitch.tv',
#   'Country': {'Rank': '13',
#    'Reach': {'PerMillion': '48070'},
#    'PageViews': {'PerMillion': '3299', 'PerUser': '2.99'}},
#   'Global': {'Rank': '26'}},
#  {'DataUrl': 'microsoftonline.com',
#   'Country': {'Rank': '14',
#    'Reach': {'PerMillion': '51850'},
#    'PageViews': {'PerMillion': '2184', 'PerUser': '1.83'}},
#   'Global': {'Rank': '33'}},
#  {'DataUrl': 'pornhub.com',
#   'Country': {'Rank': '15',
#    'Reach': {'PerMillion': '32840'},
#    'PageViews': {'PerMillion': '2709', 'PerUser': '3.59'}},
#   'Global': {'Rank': '28'}},
#  {'DataUrl': 'imgur.com',
#   'Country': {'Rank': '16',
#    'Reach': {'PerMillion': '33830'},
#    'PageViews': {'PerMillion': '1924', 'PerUser': '2.47'}},
#   'Global': {'Rank': '58'}},
#  {'DataUrl': 'craigslist.org',
#   'Country': {'Rank': '17',
#    'Reach': {'PerMillion': '23290'},
#    'PageViews': {'PerMillion': '4330', 'PerUser': '8.09'}},
#   'Global': {'Rank': '113'}},
#  {'DataUrl': 'live.com',
#   'Country': {'Rank': '18',
#    'Reach': {'PerMillion': '28650'},
#    'PageViews': {'PerMillion': '2199', 'PerUser': '3.34'}},
#   'Global': {'Rank': '15'}},
#  {'DataUrl': 'paypal.com',
#   'Country': {'Rank': '19',
#    'Reach': {'PerMillion': '24060'},
#    'PageViews': {'PerMillion': '2680', 'PerUser': '4.85'}},
#   'Global': {'Rank': '56'}},
#  {'DataUrl': 'chase.com',
#   'Country': {'Rank': '20',
#    'Reach': {'PerMillion': '25190'},
#    'PageViews': {'PerMillion': '2303', 'PerUser': '3.98'}},
#   'Global': {'Rank': '129'}},
#  {'DataUrl': 'bing.com',
#   'Country': {'Rank': '21',
#    'Reach': {'PerMillion': '27640'},
#    'PageViews': {'PerMillion': '1651', 'PerUser': '2.6'}},
#   'Global': {'Rank': '38'}},
#  {'DataUrl': 'instructure.com',
#   'Country': {'Rank': '22',
#    'Reach': {'PerMillion': '19910'},
#    'PageViews': {'PerMillion': '3859', 'PerUser': '8.44'}},
#   'Global': {'Rank': '124'}},
#  {'DataUrl': 'espn.com',
#   'Country': {'Rank': '23',
#    'Reach': {'PerMillion': '27000'},
#    'PageViews': {'PerMillion': '1548', 'PerUser': '2.49'}},
#   'Global': {'Rank': '116'}},
#  {'DataUrl': 'fandom.com',
#   'Country': {'Rank': '24',
#    'Reach': {'PerMillion': '22700'},
#    'PageViews': {'PerMillion': '2324', 'PerUser': '4.45'}},
#   'Global': {'Rank': '55'}},
#  {'DataUrl': 'cnn.com',
#   'Country': {'Rank': '25',
#    'Reach': {'PerMillion': '27240'},
#    'PageViews': {'PerMillion': '1424', 'PerUser': '2.27'}},
#   'Global': {'Rank': '102'}},
#  {'DataUrl': 'imdb.com',
#   'Country': {'Rank': '26',
#    'Reach': {'PerMillion': '21760'},
#    'PageViews': {'PerMillion': '1976', 'PerUser': '3.95'}},
#   'Global': {'Rank': '48'}},
#  {'DataUrl': 'pinterest.com',
#   'Country': {'Rank': '27',
#    'Reach': {'PerMillion': '22400'},
#    'PageViews': {'PerMillion': '1643', 'PerUser': '3.19'}},
#   'Global': {'Rank': '69'}},
#  {'DataUrl': 't.co',
#   'Country': {'Rank': '28',
#    'Reach': {'PerMillion': '26010'},
#    'PageViews': {'PerMillion': '1179', 'PerUser': '1.97'}},
#   'Global': {'Rank': '41'}},
#  {'DataUrl': 'nytimes.com',
#   'Country': {'Rank': '29',
#    'Reach': {'PerMillion': '23420'},
#    'PageViews': {'PerMillion': '1236', 'PerUser': '2.3'}},
#   'Global': {'Rank': '114'}},
#  {'DataUrl': 'office.com',
#   'Country': {'Rank': '30',
#    'Reach': {'PerMillion': '20960'},
#    'PageViews': {'PerMillion': '1483', 'PerUser': '3.08'}},
#   'Global': {'Rank': '50'}},
#  {'DataUrl': 'hulu.com',
#   'Country': {'Rank': '31',
#    'Reach': {'PerMillion': '24710'},
#    'PageViews': {'PerMillion': '986.7', 'PerUser': '1.74'}},
#   'Global': {'Rank': '172'}},
#  {'DataUrl': 'okezone.com',
#   'Country': {'Rank': '32',
#    'Reach': {'PerMillion': '43804.35'},
#    'PageViews': {'PerMillion': '1896.47', 'PerUser': '1.88'}},
#   'Global': {'Rank': '54'}},
#  {'DataUrl': 'microsoft.com',
#   'Country': {'Rank': '33',
#    'Reach': {'PerMillion': '19930'},
#    'PageViews': {'PerMillion': '1346', 'PerUser': '2.94'}},
#   'Global': {'Rank': '37'}},
#  {'DataUrl': 'github.com',
#   'Country': {'Rank': '34',
#    'Reach': {'PerMillion': '17200'},
#    'PageViews': {'PerMillion': '1992', 'PerUser': '5.04'}},
#   'Global': {'Rank': '46'}},
#  {'DataUrl': 'salesforce.com',
#   'Country': {'Rank': '35',
#    'Reach': {'PerMillion': '13200'},
#    'PageViews': {'PerMillion': '4525', 'PerUser': '14.9'}},
#   'Global': {'Rank': '119'}},
#  {'DataUrl': 'force.com',
#   'Country': {'Rank': '36',
#    'Reach': {'PerMillion': '14300'},
#    'PageViews': {'PerMillion': '3147', 'PerUser': '9.55'}},
#   'Global': {'Rank': '115'}},
#  {'DataUrl': 'zillow.com',
#   'Country': {'Rank': '37',
#    'Reach': {'PerMillion': '17100'},
#    'PageViews': {'PerMillion': '1747', 'PerUser': '4.44'}},
#   'Global': {'Rank': '196'}},
#  {'DataUrl': 'walmart.com',
#   'Country': {'Rank': '38',
#    'Reach': {'PerMillion': '17300'},
#    'PageViews': {'PerMillion': '1570', 'PerUser': '3.94'}},
#   'Global': {'Rank': '166'}},
#  {'DataUrl': 'yelp.com',
#   'Country': {'Rank': '39',
#    'Reach': {'PerMillion': '18110'},
#    'PageViews': {'PerMillion': '1358', 'PerUser': '3.26'}},
#   'Global': {'Rank': '198'}},
#  {'DataUrl': 'weather.com',
#   'Country': {'Rank': '40',
#    'Reach': {'PerMillion': '18520'},
#    'PageViews': {'PerMillion': '1086', 'PerUser': '2.55'}},
#   'Global': {'Rank': '200'}},
#  {'DataUrl': 'apple.com',
#   'Country': {'Rank': '41',
#    'Reach': {'PerMillion': '17300'},
#    'PageViews': {'PerMillion': '1250', 'PerUser': '3.15'}},
#   'Global': {'Rank': '61'}},
#  {'DataUrl': 'bankofamerica.com',
#   'Country': {'Rank': '42',
#    'Reach': {'PerMillion': '14000'},
#    'PageViews': {'PerMillion': '1863', 'PerUser': '5.81'}},
#   'Global': {'Rank': '215'}},
#  {'DataUrl': 'tumblr.com',
#   'Country': {'Rank': '43',
#    'Reach': {'PerMillion': '14000'},
#    'PageViews': {'PerMillion': '1684', 'PerUser': '5.25'}},
#   'Global': {'Rank': '74'}},
#  {'DataUrl': 'stackoverflow.com',
#   'Country': {'Rank': '44',
#    'Reach': {'PerMillion': '15500'},
#    'PageViews': {'PerMillion': '1260', 'PerUser': '3.54'}},
#   'Global': {'Rank': '51'}},
#  {'DataUrl': 'dropbox.com',
#   'Country': {'Rank': '45',
#    'Reach': {'PerMillion': '15900'},
#    'PageViews': {'PerMillion': '1102', 'PerUser': '3.02'}},
#   'Global': {'Rank': '77'}},
#  {'DataUrl': 'livejasmin.com',
#   'Country': {'Rank': '46',
#    'Reach': {'PerMillion': '30491.73'},
#    'PageViews': {'PerMillion': '1031', 'PerUser': '1.47'}},
#   'Global': {'Rank': '52'}},
#  {'DataUrl': 'xvideos.com',
#   'Country': {'Rank': '47',
#    'Reach': {'PerMillion': '11500'},
#    'PageViews': {'PerMillion': '2624', 'PerUser': '9.96'}},
#   'Global': {'Rank': '47'}},
#  {'DataUrl': 'wellsfargo.com',
#   'Country': {'Rank': '48',
#    'Reach': {'PerMillion': '13400'},
#    'PageViews': {'PerMillion': '1505', 'PerUser': '4.9'}},
#   'Global': {'Rank': '239'}},
#  {'DataUrl': 'indeed.com',
#   'Country': {'Rank': '49',
#    'Reach': {'PerMillion': '14000'},
#    'PageViews': {'PerMillion': '1200', 'PerUser': '3.74'}},
#   'Global': {'Rank': '137'}},
#  {'DataUrl': 'quora.com',
#   'Country': {'Rank': '50',
#    'Reach': {'PerMillion': '18510'},
#    'PageViews': {'PerMillion': '651.4', 'PerUser': '1.53'}},
#   'Global': {'Rank': '80'}},
#  {'DataUrl': 'etsy.com',
#   'Country': {'Rank': '51',
#    'Reach': {'PerMillion': '12400'},
#    'PageViews': {'PerMillion': '1626', 'PerUser': '5.71'}},
#   'Global': {'Rank': '144'}},
#  {'DataUrl': 'amazonaws.com',
#   'Country': {'Rank': '52',
#    'Reach': {'PerMillion': '15500'},
#    'PageViews': {'PerMillion': '775.4', 'PerUser': '2.18'}},
#   'Global': {'Rank': '98'}},
#  {'DataUrl': 'adobe.com',
#   'Country': {'Rank': '53',
#    'Reach': {'PerMillion': '13800'},
#    'PageViews': {'PerMillion': '978.4', 'PerUser': '3.08'}},
#   'Global': {'Rank': '62'}},
#  {'DataUrl': 'blogspot.com',
#   'Country': {'Rank': '54',
#    'Reach': {'PerMillion': '15100'},
#    'PageViews': {'PerMillion': '737.7', 'PerUser': '2.13'}},
#   'Global': {'Rank': '23'}},
#  {'DataUrl': 'quizlet.com',
#   'Country': {'Rank': '55',
#    'Reach': {'PerMillion': '12000'},
#    'PageViews': {'PerMillion': '1223', 'PerUser': '4.42'}},
#   'Global': {'Rank': '219'}},
#  {'DataUrl': 'spotify.com',
#   'Country': {'Rank': '56',
#    'Reach': {'PerMillion': '13300'},
#    'PageViews': {'PerMillion': '888.7', 'PerUser': '2.9'}},
#   'Global': {'Rank': '107'}},
#  {'DataUrl': 'msn.com',
#   'Country': {'Rank': '57',
#    'Reach': {'PerMillion': '12400'},
#    'PageViews': {'PerMillion': '1010', 'PerUser': '3.54'}},
#   'Global': {'Rank': '53'}},
#  {'DataUrl': 'foxnews.com',
#   'Country': {'Rank': '58',
#    'Reach': {'PerMillion': '12800'},
#    'PageViews': {'PerMillion': '904', 'PerUser': '3.08'}},
#   'Global': {'Rank': '253'}},
#  {'DataUrl': 'xfinity.com',
#   'Country': {'Rank': '59',
#    'Reach': {'PerMillion': '12500'},
#    'PageViews': {'PerMillion': '932.1', 'PerUser': '3.25'}},
#   'Global': {'Rank': '291'}},
#  {'DataUrl': 'homedepot.com',
#   'Country': {'Rank': '60',
#    'Reach': {'PerMillion': '11200'},
#    'PageViews': {'PerMillion': '1183', 'PerUser': '4.58'}},
#   'Global': {'Rank': '284'}},
#  {'DataUrl': 'discordapp.com',
#   'Country': {'Rank': '61',
#    'Reach': {'PerMillion': '13700'},
#    'PageViews': {'PerMillion': '681.2', 'PerUser': '2.17'}},
#   'Global': {'Rank': '118'}},
#  {'DataUrl': 'soundcloud.com',
#   'Country': {'Rank': '62',
#    'Reach': {'PerMillion': '12300'},
#    'PageViews': {'PerMillion': '579.1', 'PerUser': '2.05'}},
#   'Global': {'Rank': '108'}},
#  {'DataUrl': 'wordpress.com',
#   'Country': {'Rank': '63',
#    'Reach': {'PerMillion': '12000'},
#    'PageViews': {'PerMillion': '597.5', 'PerUser': '2.17'}},
#   'Global': {'Rank': '57'}},
#  {'DataUrl': 'okta.com',
#   'Country': {'Rank': '64',
#    'Reach': {'PerMillion': '10400'},
#    'PageViews': {'PerMillion': '715', 'PerUser': '2.99'}},
#   'Global': {'Rank': '255'}},
#  {'DataUrl': 'stackexchange.com',
#   'Country': {'Rank': '65',
#    'Reach': {'PerMillion': '12100'},
#    'PageViews': {'PerMillion': '504.9', 'PerUser': '1.81'}},
#   'Global': {'Rank': '117'}},
#  {'DataUrl': 'nih.gov',
#   'Country': {'Rank': '66',
#    'Reach': {'PerMillion': '10600'},
#    'PageViews': {'PerMillion': '669.5', 'PerUser': '2.75'}},
#   'Global': {'Rank': '111'}},
#  {'DataUrl': 'bestbuy.com',
#   'Country': {'Rank': '67',
#    'Reach': {'PerMillion': '9570'},
#    'PageViews': {'PerMillion': '799.4', 'PerUser': '3.64'}},
#   'Global': {'Rank': '297'}},
#  {'DataUrl': 'breitbart.com',
#   'Country': {'Rank': '68',
#    'Reach': {'PerMillion': '15846.49'},
#    'PageViews': {'PerMillion': '1312.44', 'PerUser': '3.6'}},
#   'Global': {'Rank': '336'}},
#  {'DataUrl': 'zoom.us',
#   'Country': {'Rank': '69',
#    'Reach': {'PerMillion': '10500'},
#    'PageViews': {'PerMillion': '630.2', 'PerUser': '2.61'}},
#   'Global': {'Rank': '207'}},
#  {'DataUrl': 'capitalone.com',
#   'Country': {'Rank': '70',
#    'Reach': {'PerMillion': '9070'},
#    'PageViews': {'PerMillion': '822.1', 'PerUser': '3.94'}},
#   'Global': {'Rank': '377'}},
#  {'DataUrl': 'xhamster.com',
#   'Country': {'Rank': '71',
#    'Reach': {'PerMillion': '7240'},
#    'PageViews': {'PerMillion': '1633', 'PerUser': '9.82'}},
#   'Global': {'Rank': '59'}},
#  {'DataUrl': 'usps.com',
#   'Country': {'Rank': '72',
#    'Reach': {'PerMillion': '10200'},
#    'PageViews': {'PerMillion': '605.8', 'PerUser': '2.59'}},
#   'Global': {'Rank': '345'}},
#  {'DataUrl': 'airbnb.com',
#   'Country': {'Rank': '73',
#    'Reach': {'PerMillion': '8080'},
#    'PageViews': {'PerMillion': '1062', 'PerUser': '5.72'}},
#   'Global': {'Rank': '251'}},
#  {'DataUrl': 'intuit.com',
#   'Country': {'Rank': '74',
#    'Reach': {'PerMillion': '9060'},
#    'PageViews': {'PerMillion': '742', 'PerUser': '3.56'}},
#   'Global': {'Rank': '333'}},
#  {'DataUrl': 'bbc.com',
#   'Country': {'Rank': '75',
#    'Reach': {'PerMillion': '10000'},
#    'PageViews': {'PerMillion': '565.3', 'PerUser': '2.46'}},
#   'Global': {'Rank': '86'}},
#  {'DataUrl': 'redd.it',
#   'Country': {'Rank': '76',
#    'Reach': {'PerMillion': '10700'},
#    'PageViews': {'PerMillion': '479.8', 'PerUser': '1.96'}},
#   'Global': {'Rank': '224'}},
#  {'DataUrl': 'slickdeals.net',
#   'Country': {'Rank': '77',
#    'Reach': {'PerMillion': '9330'},
#    'PageViews': {'PerMillion': '553.7', 'PerUser': '2.58'}},
#   'Global': {'Rank': '423'}},
#  {'DataUrl': 'washingtonpost.com',
#   'Country': {'Rank': '78',
#    'Reach': {'PerMillion': '9620'},
#    'PageViews': {'PerMillion': '500', 'PerUser': '2.26'}},
#   'Global': {'Rank': '282'}},
#  {'DataUrl': 'gamepedia.com',
#   'Country': {'Rank': '79',
#    'Reach': {'PerMillion': '7570'},
#    'PageViews': {'PerMillion': '887.5', 'PerUser': '5.1'}},
#   'Global': {'Rank': '167'}},
#  {'DataUrl': 'slack.com',
#   'Country': {'Rank': '80',
#    'Reach': {'PerMillion': '8190'},
#    'PageViews': {'PerMillion': '678.5', 'PerUser': '3.61'}},
#   'Global': {'Rank': '179'}},
#  {'DataUrl': 'patch.com',
#   'Country': {'Rank': '81',
#    'Reach': {'PerMillion': '16650.53'},
#    'PageViews': {'PerMillion': '717.06', 'PerUser': '1.87'}},
#   'Global': {'Rank': '453'}},
#  {'DataUrl': 'godaddy.com',
#   'Country': {'Rank': '82',
#    'Reach': {'PerMillion': '7190'},
#    'PageViews': {'PerMillion': '966.3', 'PerUser': '5.85'}},
#   'Global': {'Rank': '157'}},
#  {'DataUrl': 'chaturbate.com',
#   'Country': {'Rank': '83',
#    'Reach': {'PerMillion': '6340'},
#    'PageViews': {'PerMillion': '1454', 'PerUser': '9.99'}},
#   'Global': {'Rank': '145'}},
#  {'DataUrl': 'tripadvisor.com',
#   'Country': {'Rank': '84',
#    'Reach': {'PerMillion': '8660'},
#    'PageViews': {'PerMillion': '568.5', 'PerUser': '2.86'}},
#   'Global': {'Rank': '263'}},
#  {'DataUrl': 'target.com',
#   'Country': {'Rank': '85',
#    'Reach': {'PerMillion': '8550'},
#    'PageViews': {'PerMillion': '563.2', 'PerUser': '2.87'}},
#   'Global': {'Rank': '436'}},
#  {'DataUrl': 'roblox.com',
#   'Country': {'Rank': '86',
#    'Reach': {'PerMillion': '6220'},
#    'PageViews': {'PerMillion': '1384', 'PerUser': '9.67'}},
#   'Global': {'Rank': '90'}},
#  {'DataUrl': 'buzzfeed.com',
#   'Country': {'Rank': '87',
#    'Reach': {'PerMillion': '7720'},
#    'PageViews': {'PerMillion': '682', 'PerUser': '3.84'}},
#   'Global': {'Rank': '259'}},
#  {'DataUrl': 'baidu.com',
#   'Country': {'Rank': '88',
#    'Reach': {'PerMillion': '7370'},
#    'PageViews': {'PerMillion': '729.1', 'PerUser': '4.3'}},
#   'Global': {'Rank': '4'}},
#  {'DataUrl': 'myshopify.com',
#   'Country': {'Rank': '89',
#    'Reach': {'PerMillion': '6130'},
#    'PageViews': {'PerMillion': '1286', 'PerUser': '9.13'}},
#   'Global': {'Rank': '216'}},
#  {'DataUrl': 'vice.com',
#   'Country': {'Rank': '90',
#    'Reach': {'PerMillion': '15955.17'},
#    'PageViews': {'PerMillion': '504.66', 'PerUser': '1.38'}},
#   'Global': {'Rank': '201'}},
#  {'DataUrl': 'citi.com',
#   'Country': {'Rank': '91',
#    'Reach': {'PerMillion': '6270'},
#    'PageViews': {'PerMillion': '954.9', 'PerUser': '6.62'}},
#   'Global': {'Rank': '489'}},
#  {'DataUrl': 'aol.com',
#   'Country': {'Rank': '92',
#    'Reach': {'PerMillion': '7410'},
#    'PageViews': {'PerMillion': '570.9', 'PerUser': '3.35'}},
#   'Global': {'Rank': '361'}},
#  {'DataUrl': 'vimeo.com',
#   'Country': {'Rank': '93',
#    'Reach': {'PerMillion': '7730'},
#    'PageViews': {'PerMillion': '508.6', 'PerUser': '2.86'}},
#   'Global': {'Rank': '128'}},
#  {'DataUrl': 'americanexpress.com',
#   'Country': {'Rank': '94',
#    'Reach': {'PerMillion': '7240'},
#    'PageViews': {'PerMillion': '588.2', 'PerUser': '3.54'}},
#   'Global': {'Rank': '348'}},
#  {'DataUrl': 'steamcommunity.com',
#   'Country': {'Rank': '95',
#    'Reach': {'PerMillion': '8450'},
#    'PageViews': {'PerMillion': '410', 'PerUser': '2.11'}},
#   'Global': {'Rank': '147'}},
#  {'DataUrl': 'glassdoor.com',
#   'Country': {'Rank': '96',
#    'Reach': {'PerMillion': '7080'},
#    'PageViews': {'PerMillion': '596', 'PerUser': '3.67'}},
#   'Global': {'Rank': '414'}},
#  {'DataUrl': 'gfycat.com',
#   'Country': {'Rank': '97',
#    'Reach': {'PerMillion': '11663.11'},
#    'PageViews': {'PerMillion': '825.27', 'PerUser': '3.08'}},
#   'Global': {'Rank': '260'}},
#  {'DataUrl': 'xnxx.com',
#   'Country': {'Rank': '98',
#    'Reach': {'PerMillion': '5230'},
#    'PageViews': {'PerMillion': '1246', 'PerUser': '10.4'}},
#   'Global': {'Rank': '99'}},
#  {'DataUrl': 'ups.com',
#   'Country': {'Rank': '99',
#    'Reach': {'PerMillion': '7760'},
#    'PageViews': {'PerMillion': '360', 'PerUser': '2.02'}},
#   'Global': {'Rank': '406'}},
#  {'DataUrl': 'tmall.com',
#   'Country': {'Rank': '100',
#    'Reach': {'PerMillion': '6470'},
#    'PageViews': {'PerMillion': '517.5', 'PerUser': '3.48'}},
#   'Global': {'Rank': '7'}}]

# %%
import requests as r

# %%
from bs4 import BeautifulSoup
import time

# %%
scan_start = time.process_time_ns()
for site in hundred_sites:
    site_scan_start = time.process_time_ns()
    site_url = site["DataUrl"]
    print("Started analyzing {} at {}".format(site_url, site_scan_start))
    site_request = r.get("https://{}".format(site_url))
    site_text = site_request.text
    site_headers = site_request.headers
    site_soup = BeautifulSoup(site_text, "lxml")
    site_word_count = len(site_soup.text.split())
    print("Word count for {} is {}".format(site_url, site_word_count))
    site_scan_stop = time.process_time_ns()
    print("Stoped analyzing {} at {}, it took {} nanoseconds".format(site_url, site_scan_stop, site_scan_stop-site_scan_start))
scan_stop = time.process_time_ns()
# Out:
# Started analyzing google.com at 3567927000
# Word count for google.com is 133
# Stoped analyzing google.com at 3608171000, it took 40244000 nanoseconds
# Started analyzing youtube.com at 3608249000
# Word count for youtube.com is 3037
# Stoped analyzing youtube.com at 3787561000, it took 179312000 nanoseconds
# Started analyzing facebook.com at 3787619000
# Word count for facebook.com is 1051
# Stoped analyzing facebook.com at 3846983000, it took 59364000 nanoseconds
# Started analyzing amazon.com at 3847036000
# Word count for amazon.com is 131
# Stoped analyzing amazon.com at 3888218000, it took 41182000 nanoseconds
# Started analyzing reddit.com at 3888245000
# Word count for reddit.com is 125
# Stoped analyzing reddit.com at 3923745000, it took 35500000 nanoseconds
# Started analyzing wikipedia.org at 3923774000
# Word count for wikipedia.org is 1499
# Stoped analyzing wikipedia.org at 3998198000, it took 74424000 nanoseconds
# Started analyzing yahoo.com at 3998266000
# Word count for yahoo.com is 10574
# Stoped analyzing yahoo.com at 4090259000, it took 91993000 nanoseconds
# Started analyzing twitter.com at 4090299000
# Word count for twitter.com is 699
# Stoped analyzing twitter.com at 4142877000, it took 52578000 nanoseconds
# Started analyzing instagram.com at 4142915000
# Word count for instagram.com is 629
# Stoped analyzing instagram.com at 4185847000, it took 42932000 nanoseconds
# Started analyzing linkedin.com at 4185881000
# Word count for linkedin.com is 281
# Stoped analyzing linkedin.com at 4240208000, it took 54327000 nanoseconds
# Started analyzing ebay.com at 4240247000
# Word count for ebay.com is 1963
# Stoped analyzing ebay.com at 4341487000, it took 101240000 nanoseconds
# Started analyzing netflix.com at 4341526000
# Word count for netflix.com is 274
# Stoped analyzing netflix.com at 4399334000, it took 57808000 nanoseconds
# Started analyzing twitch.tv at 4399362000
# Word count for twitch.tv is 105
# Stoped analyzing twitch.tv at 4436019000, it took 36657000 nanoseconds
# Started analyzing microsoftonline.com at 4436056000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-4738a53a041f> in <module>()
#       4     site_url = site["DataUrl"]
#       5     print("Started analyzing {} at {}".format(site_url, site_scan_start))
# ----> 6     site_request = r.get("https://{}".format(site_url))
#       7     site_text = site_request.text
#       8     site_headers = site_request.headers
#
# ~/code/envs/scratch/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/code/envs/scratch/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/code/envs/scratch/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/code/envs/scratch/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/code/envs/scratch/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/code/envs/scratch/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/code/envs/scratch/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/code/envs/scratch/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# ~/code/envs/scratch/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     299     def connect(self):
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#     303
#
# ~/code/envs/scratch/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     157         try:
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#     161         except SocketTimeout as e:
#
# ~/code/envs/scratch/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      68             if source_address:
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#      72
#
# KeyboardInterrupt:

# %%
site_scan_start = time.process_time_ns()
# site_url = site["DataUrl"]
site_url = "microsoftonline.com"
print("Started analyzing {} at {}".format(site_url, site_scan_start))
site_request = r.get("http://{}".format(site_url))
site_text = site_request.text
site_headers = site_request.headers
site_soup = BeautifulSoup(site_text, "lxml")
site_word_count = len(site_soup.text.split())
print("Word count for {} is {}".format(site_url, site_word_count))
site_scan_stop = time.process_time_ns()
print("Stoped analyzing {} at {}, it took {} nanoseconds".format(site_url, site_scan_stop, site_scan_stop-site_scan_start))
# Out:
# Started analyzing microsoftonline.com at 4563051000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-f54634eceedc> in <module>()
#       3 site_url = "microsoftonline.com"
#       4 print("Started analyzing {} at {}".format(site_url, site_scan_start))
# ----> 5 site_request = r.get("http://{}".format(site_url))
#       6 site_text = site_request.text
#       7 site_headers = site_request.headers
#
# ~/code/envs/scratch/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/code/envs/scratch/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/code/envs/scratch/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/code/envs/scratch/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/code/envs/scratch/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/code/envs/scratch/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/code/envs/scratch/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     352             conn.request_chunked(method, url, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#     356         # Reset the timeout for the recv() on the socket
#
# /usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1227                 encode_chunked=False):
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#    1231     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1273             # default charset of iso-8859-1.
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#    1277     def getresponse(self):
#
# /usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1222         else:
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#    1226     def request(self, method, url, body=None, headers={}, *,
#
# /usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1014         msg = b"\r\n".join(self._buffer)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#    1018         if message_body is not None:
#
# /usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in send(self, data)
#     954         if self.sock is None:
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#     958                 raise NotConnected()
#
# ~/code/envs/scratch/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     179
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#     183
#
# ~/code/envs/scratch/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     157         try:
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#     161         except SocketTimeout as e:
#
# ~/code/envs/scratch/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      68             if source_address:
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#      72
#
# KeyboardInterrupt:
